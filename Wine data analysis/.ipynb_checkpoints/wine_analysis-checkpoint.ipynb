# %%
#!/usr/bin/env python3
# coding=utf-8

"""Analysis of wine data"""

__author__ = "Rachel Wang"

# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# pygal maps for country distribution
import pygal.maps.world 
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model

# %%
# load data from csv file
# set index_col = 0 to avoid adding Unnamed: 0 column when use pd.read_csv
wineData = pd.read_csv("/Users/rwang/PycharmProjects/Kaggle_projects/Wine data analysis/winemag-data_first150k.csv", index_col=0)
# check wineData info and describe
wineData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150930 entries, 0 to 150929
# Data columns (total 10 columns):
# country        150925 non-null object
# description    150930 non-null object
# designation    105195 non-null object
# points         150930 non-null int64
# price          137235 non-null float64
# province       150925 non-null object
# region_1       125870 non-null object
# region_2       60953 non-null object
# variety        150930 non-null object
# winery         150930 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 12.7+ MB

# %% [markdown]
# ## Report Result:
# Except points and price are numeric, others are objects. <br>
# country, designation, price, province, region_1 region_2 have missing values

# %%
wineData.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %% [markdown]
# ## Report Result:
# The maximum points is 100, minimum is 80. std=3.22 means variance of points is not too much.<br>
# The maximum price is 2300, minimum is 4. The std is 36.32. It is a large value means prices have a big difference.

# %%
# check duplicated value
wineData.duplicated().value_counts()
# Out:
# False    97851
# True     53079
# dtype: int64

# %%
duplicateRows = wineData[wineData.duplicated()]
 
#print("Duplicate Rows except first occurrence based on all columns are :")
#print(duplicateRows)

# remove duplicated rows 
wineData.drop_duplicates(inplace=True)

# %%
# check basic info. No much change
wineData.info()
wineData.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97851 entries, 0 to 149639
# Data columns (total 10 columns):
# country        97848 non-null object
# description    97851 non-null object
# designation    67955 non-null object
# points         97851 non-null int64
# price          89131 non-null float64
# province       97848 non-null object
# region_1       81919 non-null object
# region_2       39491 non-null object
# variety        97851 non-null object
# winery         97851 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 8.2+ MB
#              points         price
# count  97851.000000  89131.000000
# mean      87.956730     33.658783
# std        3.218138     37.670180
# min       80.000000      4.000000
# 25%       86.000000     16.000000
# 50%       88.000000     25.000000
# 75%       90.000000     40.000000
# max      100.000000   2300.000000

# %% [markdown]
# # Analyze info of wine data
# ## Questions
# - 1. Which varieties are popular?
# - 2. Within popular varities, which ones have the higher price and higher points?
# - 3. What the relationship between price and point? (positive correlation?)
# - 4. How is the country distibution of wine production?

# %%
# Draw bar chat for varitiy
topVarieties = wineData.variety.value_counts()[0:10]
ax = topVarieties.plot(kind='bar', title='top 10 of Wine Varieties')
plt.ylabel('Counts', fontsize=12)
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# ## Result of the first question
# The top 10 popular wine varieties are:
# - 1. Pinot Noir,
# - 2. Chardonnay,
# - 3. Cabernet Sauvignon,
# - 4. Red Blend,
# - 5. Bordeaux-style Red Blend,
# - 6. Sauvignon Blanc,
# - 7. Syrah,
# - 8. Riesling,
# - 9. Merlot
# - 10. Zinfandel

# %%
# Draw boxplot to find which varities have higher price

# select data which variety is in top 10 varieties
topVaritiesDf = wineData[wineData.variety.isin(topVarieties.index)]

# use sns plot boxplot
plt.figure(figsize=(12, 8))
plt.ylim([0, 125])
ax = sns.boxplot(x='variety', y="price", data=topVaritiesDf, palette="Blues")
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Cabernet Sauvignon'),
#  Text(0, 0, 'Sauvignon Blanc'),
#  Text(0, 0, 'Pinot Noir'),
#  Text(0, 0, 'Chardonnay'),
#  Text(0, 0, 'Syrah'),
#  Text(0, 0, 'Red Blend'),
#  Text(0, 0, 'Riesling'),
#  Text(0, 0, 'Zinfandel'),
#  Text(0, 0, 'Bordeaux-style Red Blend'),
#  Text(0, 0, 'Merlot')]

# %% [markdown]
# ## Plus a note:
# ### Difference between bar chat and histogram
# - 1. A histogram represents the frequency distribution of continuous variables. <br>
#      A bar graph is a diagrammatic comparison of discrete variables.
# - 2. Histogram presents numerical data whereas bar graph shows categorical data.
# - 3. The histogram is drawn in such a way that there is no gap between the bars.

# %%
# Draw boxplot to find which varities have higher points
plt.figure(figsize=(12, 8))
ax = sns.boxplot(x='variety', y="points", data=topVaritiesDf, palette="Blues")
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Cabernet Sauvignon'),
#  Text(0, 0, 'Sauvignon Blanc'),
#  Text(0, 0, 'Pinot Noir'),
#  Text(0, 0, 'Chardonnay'),
#  Text(0, 0, 'Syrah'),
#  Text(0, 0, 'Red Blend'),
#  Text(0, 0, 'Riesling'),
#  Text(0, 0, 'Zinfandel'),
#  Text(0, 0, 'Bordeaux-style Red Blend'),
#  Text(0, 0, 'Merlot')]

# %% [markdown]
# ## Result of the second question
# (According to mean)
# - 1. Bordeaux-style Red Blend, Pinot Noir, and Cabernet Sauvignon have higher price.
# - 2. Still Bordeaux-style Red Blend, Pinot Noir, and Cabernet Sauvignon have higher mean of points.
#
# <br>
# We could get a conclusion: more expensive, taste better. <br>
# Let's find if there is positive correlation between price and points

# %%
# draw price distribution
plt.figure(figsize=(8,8))
sns.distplot(wineData.price.dropna(), kde=False)

# %% [markdown]
# ## Report about price distribution
# We could know most price of wines are less than 200. The quantity of price greater than 500 is small. The wine with price greater than 500 will belong to senior wine.

# %%
# use mathmatic to prove most price is less than 200
# more than 90% price of wines is less than 200
price_less200 = wineData.loc[wineData['price'] < 200]
price_greater500 = wineData.loc[wineData['price'] > 500]
ratio_less200 = len(price_less200) / len(wineData)
ratio_greater500 = len(price_greater500) / len(wineData)
f'The ratio of price less 200 is {ratio_less200} and the ratio of price greater than 500 is {ratio_greater500}.'
# Out:
# 'The ratio of price less 200 is 0.9049881963393323 and the ratio of price greater than 500 is 0.0005518594597909066.'

# %%
# find the relationship between price and points
all_pricePoint = wineData['price'].corr(wineData['points'])
less200_pricePoint = price_less200['price'].corr(price_less200['points'])
print(f'The overall correlation coefficient for price and points is {all_pricePoint}.')
print(f'The correlation coefficient for price less than 200 and points is {less200_pricePoint}.')
# Out:
# The overall correlation coefficient for price and points is 0.44735483119723424.
# The correlation coefficient for price less than 200 and points is 0.5435706739459415.

# %% [markdown]
# ## Result of correlation between price and points
# We could know when we limit the range of price. The positive correlation is stronger. <br>
# Thus, it will have other factor to impact the price of wines when the price becomes higher. <br>
# For example, the cost of commerical.

# %%
# plot regression for price less than 200 and points
sns.lmplot(x='price',y='points',data= price_less200)

# %%
## Build linear regression model to instruct wine's choice

# %%
x = np.array(price_less200['price']).reshape(-1, 1)
y = np.array(price_less200['points']).reshape(-1, 1)
reg = linear_model.LinearRegression()
reg.fit(x, y)
intercept = reg.intercept_
coef = reg.coef_
print('Intercept: \n', intercept)
print('Coefficients: \n', coef)
print('Regression model is:')
print(f'y={coef}*x+{intercept}')
# Out:
# Intercept:
#  [85.53587271]
# Coefficients:
#  [[0.07224673]]
# Regression model is:
# y=[[0.07224673]]*x+[85.53587271]

# %% [markdown]
# ## Tips for wine's choice
# The linear regression will help choose wines with high cost-effective. If you want to choose wine with price less than
# 200 and taste good. Please pay attention to below data. Choose one of them.

# %%
# Let's find the wines whose price is less than 200 with high cost-effective 
wine_good= price_less200.copy()
wine_good['points_reg']=coef[0]*wine_good.price + intercept
wine_good = wine_good[wine_good.points > wine_good.points_reg].reset_index(drop=True)
wine_good
# Out:
#            country                                        description  \
# 0            Spain  Ripe aromas of fig, blackberry and cassis are ...
# 1               US  Mac Watson honors the memory of a wine once ma...
# 2               US  This spent 20 months in 30% new French oak, an...
# 3           France  This is the top wine from La Bégude, named aft...
# 4            Spain  Deep, dense and pure from the opening bell, th...
# 5            Spain  Slightly gritty black-fruit aromas include a s...
# 6            Spain  Lush cedary black-fruit aromas are luxe and of...
# 7               US  This re-named vineyard was formerly bottled as...
# 8               US  The producer sources from two blocks of the vi...
# 9            Italy  Elegance, complexity and structure come togeth...
# 10              US  From 18-year-old vines, this supple well-balan...
# 11              US  A standout even in this terrific lineup of 201...
# 12          France  This wine is in peak condition. The tannins an...
# 13              US  First made in 2006, this succulent luscious Ch...
# 14           Spain  Nicely oaked blackberry, licorice, vanilla and...
# 15              US  This fresh and lively medium-bodied wine is be...
# 16              US  Heitz has made this stellar rosé from the rare...
# 17           Spain  Alluring, complex and powerful aromas of grill...
# 18              US  The apogee of this ambitious winery's white wi...
# 19              US  San Jose-based producer Adam Comartin heads 1,...
# 20     New Zealand  Yields were down in 2015, but intensity is up,...
# 21              US  Bergström has made a Shea designate since 2003...
# 22              US  Focused and dense, this intense wine captures ...
# 23              US  Cranberry, baked rhubarb, anise and crushed sl...
# 24              US  This standout Rocks District wine brings earth...
# 25        Bulgaria  This Bulgarian Mavrud presents the nose with s...
# 26              US  Steely and perfumed, this wine sees only 20% n...
# 27          France  Pale in color, this is nutty in character, wit...
# 28              US  The aromas entice with notes of wet stone, hon...
# 29          France  Gingery spice notes accent fresh pear and melo...
# ...            ...                                                ...
# 46023      Austria  Lean and focused, with crisp green apple and l...
# 46024    Australia  Here's a variety you never see, let alone from...
# 46025           US  Sprightly in the mouth, this wine has lemon ve...
# 46026    Australia  This Adelaide Hills Riesling has lively acidit...
# 46027           US  Strong new barrel flavors, surprising in a win...
# 46028           US  A hint of petrol on the nose designates this a...
# 46029      Austria  Filled with blackberries and pepper on the nos...
# 46030    Australia  This is a Riesling for every day, not too inte...
# 46031           US  This Redblend of 61% Merlot, 28% Cabernet Sauv...
# 46032    Australia  Not impressive out of the gate—a pithy, stalky...
# 46033    Australia  Aromas are of intense, ripe blackberry fruit h...
# 46034           US  This dry white enters the mouth on the grassy,...
# 46035      Austria  The 2004 vintage didn't yield blockbuster Grün...
# 46036    Argentina  Fresh, tropical, and welcoming. Sweet and lush...
# 46037    Australia  Get past the Sweet Tart-y aromas and you'll be...
# 46038    Australia  Very dry, as Clare Rieslings should be, this i...
# 46039    Australia  This Chard has good intensity and length for a...
# 46040       France  Starts off slightly nutty, but also boasts pea...
# 46041    Australia  Has very nice spicy, smoky aromas and a hearty...
# 46042       France  When your name is Alphonse Mellot, you have li...
# 46043       France  Plump and succulent, with an appealing persona...
# 46044       France  Immediately attractive currant and gooseberry ...
# 46045    Australia  Two-thirds Chardonnay with Verdelho making up ...
# 46046       France  Now owned by Guy Saget of Pouilly-sur-Loire, B...
# 46047           US  Tastes beautifully rich in orange and vanilla ...
# 46048    Australia  This medium-sized, food-friendly Cab isn't fan...
# 46049           US  More oak is evident in this wine than Osprey D...
# 46050      Austria  Starts off with deep petrol and mineral notes ...
# 46051       France  Minerally on the nose, but backed by ample fru...
# 46052           US  Very fresh and crisp, with mixed flavors of me...
#
#                                 designation  points  price  \
# 0      Carodorum Selección Especial Reserva      96  110.0
# 1             Special Selected Late Harvest      96   90.0
# 2                                   Reserve      96   65.0
# 3                                La Brûlade      95   66.0
# 4                                 Numanthia      95   73.0
# 5                                 San Román      95   65.0
# 6                   Carodorum Único Crianza      95  110.0
# 7                                    Silice      95   65.0
# 8                      Gap's Crown Vineyard      95   60.0
# 9                        Ronco della Chiesa      95   80.0
# 10          Estate Vineyard Wadensvil Block      95   48.0
# 11                           Weber Vineyard      95   48.0
# 12                  Château Montus Prestige      95   90.0
# 13                                   Sigrid      95   90.0
# 14                   6 Años Reserva Premium      95   80.0
# 15                     Gap's Crown Vineyard      95   75.0
# 16                               Grignolino      95   24.0
# 17                  Prado Enea Gran Reserva      95   79.0
# 18                            Giallo Solare      95   60.0
# 19                            R-Bar-R Ranch      95   45.0
# 20                          Maté's Vineyard      94   57.0
# 21                            Shea Vineyard      94   62.0
# 22                                  Abetina      94  105.0
# 23                          Garys' Vineyard      94   60.0
# 24                          The Funk Estate      94   60.0
# 25                                  Bergulé      90   15.0
# 26                                 Babushka      90   37.0
# 27               Nonpareil Trésor Rosé Brut      90   22.0
# 28                      Conner Lee Vineyard      90   42.0
# 29                                      NaN      90   60.0
# ...                                     ...     ...    ...
# 46023                           Riedencuvée      87   14.0
# 46024                                   NaN      87   14.0
# 46025                                   NaN      87   15.0
# 46026                                   NaN      87   13.0
# 46027                                   NaN      87   12.0
# 46028                                   NaN      87   13.0
# 46029                   Fasangarten Classic      87   17.0
# 46030                             Iron Knob      87   16.0
# 46031                           Rock Island      87   14.0
# 46032                                   NaN      87   13.0
# 46033                          dB Selection      87    9.0
# 46034                                   NaN      87   15.0
# 46035                         Lössterrassen      87   10.0
# 46036                                   NaN      87    9.0
# 46037                                   NaN      87   15.0
# 46038                                   NaN      87   14.0
# 46039                         Moore's Creek      87   10.0
# 46040                                   NaN      87   11.0
# 46041                                   NaN      87   19.0
# 46042                          La Moussière      87   20.0
# 46043                       Cuvée Balthazar      87   13.0
# 46044                          Les Baronnes      87   20.0
# 46045                                   NaN      87   15.0
# 46046                          Le Chatillet      87   15.0
# 46047                               ReZerve      87   15.0
# 46048                           The Benefit      87   15.0
# 46049                                   NaN      87   18.0
# 46050                              Wachauer      87   17.0
# 46051                                   NaN      87   12.0
# 46052                         Artz Vineyard      87   17.0
#
#                  province                   region_1           region_2  \
# 0          Northern Spain                       Toro                NaN
# 1              California             Knights Valley             Sonoma
# 2                  Oregon          Willamette Valley  Willamette Valley
# 3                Provence                     Bandol                NaN
# 4          Northern Spain                       Toro                NaN
# 5          Northern Spain                       Toro                NaN
# 6          Northern Spain                       Toro                NaN
# 7                  Oregon         Chehalem Mountains  Willamette Valley
# 8              California               Sonoma Coast             Sonoma
# 9      Northeastern Italy                     Collio                NaN
# 10                 Oregon               Ribbon Ridge  Willamette Valley
# 11                 Oregon               Dundee Hills  Willamette Valley
# 12       Southwest France                    Madiran                NaN
# 13                 Oregon          Willamette Valley  Willamette Valley
# 14         Northern Spain           Ribera del Duero                NaN
# 15             California               Sonoma Coast             Sonoma
# 16             California                Napa Valley               Napa
# 17         Northern Spain                      Rioja                NaN
# 18             California                Edna Valley      Central Coast
# 19             California       Santa Cruz Mountains      Central Coast
# 20                  Kumeu                        NaN                NaN
# 21                 Oregon          Willamette Valley                NaN
# 22                 Oregon          Willamette Valley  Willamette Valley
# 23             California      Santa Lucia Highlands      Central Coast
# 24             Washington    Walla Walla Valley (WA)    Columbia Valley
# 25               Bulgaria                        NaN                NaN
# 26             California       Russian River Valley             Sonoma
# 27           France Other               Vin Mousseux                NaN
# 28             Washington       Columbia Valley (WA)    Columbia Valley
# 29           Rhône Valley        Châteauneuf-du-Pape                NaN
# ...                   ...                        ...                ...
# 46023              Vienna                        NaN                NaN
# 46024   Western Australia          Western Australia                NaN
# 46025            New York               Finger Lakes       Finger Lakes
# 46026     South Australia             Adelaide Hills                NaN
# 46027          Washington       Columbia Valley (WA)    Columbia Valley
# 46028            New York  North Fork of Long Island        Long Island
# 46029       Thermenregion                        NaN                NaN
# 46030     South Australia             Adelaide Hills                NaN
# 46031          Washington       Columbia Valley (WA)    Columbia Valley
# 46032     Australia Other             Central Ranges                NaN
# 46033     Australia Other    South Eastern Australia                NaN
# 46034          California           Dry Creek Valley             Sonoma
# 46035            Kremstal                        NaN                NaN
# 46036    Mendoza Province                 Uco Valley                NaN
# 46037   Western Australia          Western Australia                NaN
# 46038     South Australia               Clare Valley                NaN
# 46039     Australia Other    South Eastern Australia                NaN
# 46040              Alsace                     Alsace                NaN
# 46041   Western Australia          Western Australia                NaN
# 46042        Loire Valley                   Sancerre                NaN
# 46043              Alsace                     Alsace                NaN
# 46044        Loire Valley                   Sancerre                NaN
# 46045   Western Australia          Western Australia                NaN
# 46046        Loire Valley                   Sancerre                NaN
# 46047          California              Amador County   Sierra Foothills
# 46048     South Australia               Clare Valley                NaN
# 46049            New York  North Fork of Long Island        Long Island
# 46050              Wachau                        NaN                NaN
# 46051              Alsace                     Alsace                NaN
# 46052          Washington               Red Mountain    Columbia Valley
#
#                          variety                        winery  points_reg
# 0                  Tinta de Toro       Bodega Carmen Rodríguez   93.483013
# 1                Sauvignon Blanc                      Macauley   92.038079
# 2                     Pinot Noir                         Ponzi   90.231910
# 3             Provence red blend          Domaine de la Bégude   90.304157
# 4                  Tinta de Toro                     Numanthia   90.809884
# 5                  Tinta de Toro                      Maurodos   90.231910
# 6                  Tinta de Toro       Bodega Carmen Rodríguez   93.483013
# 7                     Pinot Noir                     Bergström   90.231910
# 8                     Pinot Noir                     Blue Farm   89.870677
# 9                       Friulano              Borgo del Tiglio   91.315611
# 10                    Pinot Noir        Patricia Green Cellars   89.003716
# 11                    Pinot Noir        Patricia Green Cellars   89.003716
# 12                        Tannat             Vignobles Brumont   92.038079
# 13                    Chardonnay                     Bergström   92.038079
# 14                   Tempranillo                      Valduero   91.315611
# 15                    Pinot Noir                  Gary Farrell   90.954378
# 16                          Rosé                         Heitz   87.269794
# 17             Tempranillo Blend                          Muga   91.243365
# 18                    Chardonnay              Center of Effort   89.870677
# 19                    Pinot Noir                      Comartin   88.786976
# 20                    Chardonnay                   Kumeu River   89.653936
# 21                    Pinot Noir                     Bergström   90.015170
# 22                    Pinot Noir                         Ponzi   93.121780
# 23                    Pinot Noir                          Roar   89.870677
# 24                         Syrah                        Saviah   89.870677
# 25                        Mavrud                  Villa Melnik   86.619574
# 26                    Chardonnay                      Zepaltas   88.209002
# 27               Sparkling Blend                Bouvet-Ladubay   87.125301
# 28                    Chardonnay                          Buty   88.570236
# 29       Rhône-style White Blend  Clos de L'Oratoire des Papes   89.870677
# ...                          ...                           ...         ...
# 46023                   Riesling                     Wieninger   86.547327
# 46024                  Carnelian              Windshaker Ridge   86.547327
# 46025                   Riesling               Sheldrake Point   86.619574
# 46026                   Riesling                    Silverwing   86.475080
# 46027  Cabernet Sauvignon-Merlot            San Juan Vineyards   86.402834
# 46028                   Riesling            Peconic Bay Winery   86.475080
# 46029                   Zweigelt             Christian Fischer   86.764067
# 46030                   Riesling                      Longview   86.691820
# 46031   Bordeaux-style Red Blend                  Ryan Patrick   86.547327
# 46032   Sauvignon Blanc-Semillon                       Rolling   86.475080
# 46033               Petite Sirah                    De Bortoli   86.186093
# 46034            Sauvignon Blanc                 Everett Ridge   86.619574
# 46035           Grüner Veltliner                       Felsner   86.258340
# 46036                 Chardonnay             Finca El Portillo   86.186093
# 46037  Cabernet Sauvignon-Shiraz                      Fishbone   86.619574
# 46038                   Riesling                  Annie's Lane   86.547327
# 46039                 Chardonnay                     Tyrrell's   86.258340
# 46040                Pinot Blanc               W. Gisselbrecht   86.330587
# 46041         Cabernet Sauvignon                West Cape Howe   86.908561
# 46042            Sauvignon Blanc               Alphonse Mellot   86.980807
# 46043                Pinot Blanc               Lucien Albrecht   86.475080
# 46044            Sauvignon Blanc               Henri Bourgeois   86.980807
# 46045                White Blend                      Houghton   86.619574
# 46046            Sauvignon Blanc        Joseph Balland-Chapuis   86.619574
# 46047              Orange Muscat                  Sobon Estate   86.619574
# 46048         Cabernet Sauvignon                     Tim Adams   86.619574
# 46049                     Merlot             Osprey's Dominion   86.836314
# 46050           Grüner Veltliner                   Rainer Wess   86.764067
# 46051                   Riesling               W. Gisselbrecht   86.402834
# 46052            Sauvignon Blanc      Woodinville Wine Cellars   86.764067
#
# [46053 rows x 11 columns]

# %% [markdown]
# ## Create a wine recommend system

# %%
# select top 5 wine based on points in each price group
price_group = list(wineData.groupby('price').points.nlargest(5).reset_index().level_1)
# select the top wine in each price group from original dataset and store as wine_recommend
wine_recommend=wineData.loc[price_group].reset_index(drop=True)

plt.figure(figsize=(8, 8))
sns.scatterplot(y='points',x='price',hue='country',data=wine_recommend)
plt.legend(loc='lower right')

# %%
# try to use the wine recommend system
print('Please input a price you expect：')
expect_price = float(input(''))
if expect_price in list(wine_recommend.price):
    temp=wine_recommend[wine_recommend.price==expect_price]
    for i in list(temp.index):
      if temp.loc[i].designation: 
        print('recommend：%s belongs to %s from %s，price: %.1f，points: %.1f.'%(temp.loc[i].designation, temp.loc[i].variety, temp.loc[i].country,temp.loc[i].price,temp.loc[i].points))
      else:
        print('recommend：%s from %s，price: %.1f，points: %.1f.'%(temp.loc[i].variety, temp.loc[i].country, temp.loc[i].price, temp.loc[i].points))
else:
    print('please input an approprate price')
# Out:
# Please input a price you expect：
# 50
# recommend：Red Wine belongs to Bordeaux-style Red Blend from US，price: 50.0，points: 98.0.
# recommend：Allen Vineyard belongs to Chardonnay from US，price: 50.0，points: 97.0.
# recommend：Sundawg Ridge Vineyard belongs to Pinot Noir from US，price: 50.0，points: 97.0.
# recommend：Dutton Ranch Rued Vineyard belongs to Chardonnay from US，price: 50.0，points: 97.0.
# recommend：Estate belongs to Cabernet Sauvignon from US，price: 50.0，points: 97.0.

# %% [markdown]
# ## plot world map to see the productor's distriburion

# %%
# check distibution of wine productior country
# one record for country has problem. change it based on province info
wineData.loc[wineData['country'] == 'US-France', 'country'] = 'US'

# find all productors' country name
country_name = wineData.country.value_counts().index
conName_list = [name for name in country_name]

# %%
# will use pygal to plot world map. convert country name to the name in COUNTRIES dictionary in pygal
def convert_country_name(country_name):
    for i, name in enumerate(country_name):
        if name == 'US':
            country_name[i] = 'United States'
        elif name == 'Moldova':
            country_name[i] = 'Moldova, Republic of'
        elif name == 'Macedonia':
            country_name[i] = 'Macedonia, the former Yugoslav Republic of'
        elif name == 'England':
            country_name[i] = 'United Kingdom'
        elif name == 'South Korea':
            country_name[i] = 'Korea, Republic of'
    return country_name

# %%
conName_list = convert_country_name(conName_list)

# %%
def get_countryCode(country_name):
    '''Get country code. The code will be use to draw the country in world map'''
    for code, name in pygal.maps.world.COUNTRIES.items():
        if name == country_name:
            return code
    return None

# %%
countryCode = [get_countryCode(name) for name in conName_list ]

# %%
worldmap_chart = pygal.maps.world.World()
worldmap_chart.add('countries', countryCode)
# save map as country_distribution.svg
worldmap_chart.render_to_file('country_distribution.svg')

# %%
top_country=wineData.country.value_counts()[:10]
top_country.plot(kind='pie',autopct='%.2f%%',figsize=(8,8))
plt.legend(bbox_to_anchor=(1,1))

# %%
topCountry_name = top_country.index
topConName_list = [name for name in topCountry_name]
topConName_list = convert_country_name(topConName_list)
countryCode = [get_countryCode(name) for name in topConName_list]
worldmap_chart = pygal.maps.world.World()
worldmap_chart.add('countries', countryCode)
# save map as topCountry_distribution.svg
worldmap_chart.render_to_file('topCountry_distribution.svg')
